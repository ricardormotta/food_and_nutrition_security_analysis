# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import geopandas as gpd

# %% [markdown]
# ## Importando os dados

# %%
df = pd.read_excel("./data/treated_data.xlsx")
data_dict = pd.read_csv("./data/data_dict.csv", sep=";", encoding ='latin1')

# %%
cols = df.columns.to_list()
for i in range(len(cols)):
    cols[i] = cols[i].strip()
df.columns = cols
data_dict.loc[:,'data_cod'] = data_dict.loc[:,'data_cod'].str.strip()

for col in df.columns:
    df.loc[df.loc[:,col] == "-", col] = np.nan
    
df.replace(' ', np.nan, inplace=True)
df.replace('X', np.nan, inplace=True)

# %%
df.head()
# Out:
#    cod_mun_1  cod_mun_2          mun_name   D1      D2      D3  D4     D5  D6  \
# 0   350010.0  3500105.0        Adamantina  6.0  2214.0   256.0 NaN  248.0 NaN
# 1   350020.0  3500204.0            Adolfo  1.0   728.0   140.0 NaN   51.0 NaN
# 2   350030.0  3500303.0             Aguaí  2.0  3642.0  1274.0 NaN  645.0 NaN
# 3   350040.0  3500402.0    Águas da Prata  2.0   769.0   135.0 NaN   56.0 NaN
# 4   350050.0  3500501.0  Águas de Lindóia  4.0  1481.0   346.0 NaN  201.0 NaN
#
#    D7  ...  D91  D92  D93  D94  pop2010  pop2017  pop2018  pop2019  pop2020  \
# 0 NaN  ...  NaN  NaN  NaN  NaN  33797.0  35139.0  35023.0  35068.0  35111.0
# 1 NaN  ...  NaN  NaN  NaN  NaN   3557.0   3609.0   3571.0   3562.0   3554.0
# 2 NaN  ...  NaN  NaN  NaN  NaN  32148.0  35508.0  35954.0  36305.0  36648.0
# 3 NaN  ...  NaN  NaN  NaN  NaN   7584.0   8104.0   8137.0   8180.0   8221.0
# 4 NaN  ...  NaN  NaN  NaN  NaN  17266.0  18509.0  18599.0  18705.0  18808.0
#
#    pop2021
# 0  35153.0
# 1   3545.0
# 2  36981.0
# 3   8262.0
# 4  18908.0
#
# [5 rows x 104 columns]

# %% [markdown]
# ### Criando as funções para automatizar o cálculo das medidas

# %%
def get_year_from_data(df_data_dict, data_cod):
    return df_data_dict.loc[df_data_dict.data_cod == data_cod].year.iloc[0]

def medida_tipo_1(
    s1: pd.Series, 
    s2: pd.Series, 
    mult: int):
    return (s1 / s2) * mult

def medida_tipo_2(
    s1: pd.Series, 
    s2: pd.Series,
    s3: pd.Series,
    mult: int
):
    return mult * (s1 / (s2 + s3) )

def medida_tipo_3(
    s1: pd.Series, 
    s2: pd.Series,
    s3: pd.Series,
    mult: int
):
    return mult * ((s1+s2) / s3)

# %%
for col in df.columns:
    if col[:1] == 'D':
        df.loc[:,col] = df.loc[:,col].astype('float64', errors='ignore')

# %%
df[['D57', 'D58']]
# Out:
#       D57  D58
# 0     6.0  NaN
# 1     7.5  NaN
# 2     7.2  NaN
# 3     5.7  NaN
# 4     5.5  NaN
# ..    ...  ...
# 641  12.3  NaN
# 642   3.3  NaN
# 643   4.9  NaN
# 644   8.1  NaN
# 645   NaN  NaN
#
# [646 rows x 2 columns]

# %%
medidas_tipo_1 = {
    'M1': ['D1', 'D2', 10000],
    'M2': ['D3', 'pop2021', 100],
    'M3': ['D5', 'pop2021', 100],
    'M4': ['D6', 'D7', 1],
    'M5': ['D1', 'D8', 1],
    'M9': ['D12', 'D13', 1],
    'M12': ['D18', 'D19', 100],
    'M13': ['D20', 'D21', 1],
    'M17': ['D95', 'pop2021', 1],
    'M18': ['D30', 'D31', 1],
    'M21': ['D34', 'D35', 100],
    'M22': ['D36', 'D37', 100],
    'M23': ['D38', 'D39', 100],
    'M24': ['D40', 'D34', 100],
    'M25': ['D41', 'D42', 100],
    'M26': ['D43', 'D44', 100],
    'M27': ['D45', 'D46', 100],
    'M28': ['D47', 'D48', 100],
    'M29': ['D49', 'D35', 100],
    'M30': ['D50', 'D35', 100],
    'M31': ['D51', 'D37', 100],
    'M32': ['D52', 'D37', 100],
    'M35': ['D55', 'D56', 100],
    'M36': ['D57', 'D58', 100],
    'M39': ['D64', 'D65', 100],
    'M41': ['D68', 'D69', 100],
    'M42': ['D70', 'D71', 100],
    'M42': ['D70', 'D71', 100],
    'M43': ['D72', 'D73', 100],
    'M44': ['D74', 'D75', 100],
    'M45': ['D76', 'D75', 100],
    'M46': ['D77', 'pop2021', 10000],
    'M48': ['D79', 'D80', 1],
    'M49': ['D81', 'D16', 100],
    'M50': ['D82', 'D16', 100],
    'M51': ['D83', 'D16', 100],
    'M52': ['D84', 'D85', 1],
    'M53': ['D86', 'D87', 1],
    'M54': ['D88', 'D89', 1],
}
for k,v in medidas_tipo_1.items():
    df.loc[:,k] = medida_tipo_1(
                                df.loc[:,v[0]], 
                                df.loc[:,v[1]], 
                                v[2]
                            )

# %%
medidas_tipo_2 = {
    'M8': ['D11', 'D3', 'D5', 100],
    'M19': ['D32', 'D3', 'D5', 1],
    'M20': ['D33', 'D3', 'D5', 1],
}
for k,v in medidas_tipo_2.items():
    df.loc[:,k] = medida_tipo_2(
                                df.loc[:,v[0]], 
                                df.loc[:,v[1]], 
                                df.loc[:,v[2]], 
                                v[3]
                            )

# %%
medidas_tipo_3 = {
    'M10': ['D14', 'D15', 'D16', 100],
    'M37': ['D59', 'D60', 'D61', 100],
    'M38': ['D62', 'D63', 'D61', 100],
    'M40': ['D66', 'D67', 'D65', 100],
}
for k,v in medidas_tipo_3.items():
    df.loc[:,k] = medida_tipo_3(
                                df.loc[:,v[0]], 
                                df.loc[:,v[1]], 
                                df.loc[:,v[2]], 
                                v[3])

# %%
medidas_tipo_4 = {
    'M14': ['D22','D23','D24','D25', 'D26', 'D27'],
    'M15': ['D22', 'D23', 'D27'],
    'M16': ['D28', 'D29']
}

for k, v in medidas_tipo_4.items():
    df.loc[:,k] = df.loc[:,v].fillna(0).sum(axis=1)

# %%
# Medidas iguais ao dado original
df.loc[:,'M6'] = df.loc[:,'D9']
df.loc[:,'M7'] = df.loc[:,'D10']
df.loc[:,'M11'] = df.loc[:,'D17']
df.loc[:,'M33'] = df.loc[:,'D53']
df.loc[:,'M34'] = df.loc[:,'D54']
df.loc[:,'M36'] = df.loc[:,'D57']
df.loc[:,'M47'] = df.loc[:,'D78']
df.loc[:,'M55'] = df.loc[:,'D90']
df.loc[:,'M56'] = df.loc[:,'D91']
df.loc[:,'M57'] = df.loc[:,'D92']
df.loc[:,'M58'] = df.loc[:,'D93']
df.loc[:,'M59'] = df.loc[:,'D94']

# %%
print(
    'Percentual das medidas sem dados:', 
    round(
        100*df[
            df.columns[
                df.columns.str.slice(stop=1) == 'M'
            ]
        ].isna().all().sum() / len(df.columns),
        2
    ),
    '%'
)
# Out:
# Percentual das medidas sem dados: 14.72 %

# %%
cols_all_nan = df[
    df.columns[
        df.columns.str.slice(stop=1) == 'M'
    ]
].isna().all()

print('Medidas sem dados: ', cols_all_nan.loc[cols_all_nan==True].index.to_list())
# Out:
# Medidas sem dados:  ['M4', 'M5', 'M13', 'M17', 'M25', 'M26', 'M27', 'M28', 'M31', 'M32', 'M35', 'M48', 'M52', 'M53', 'M54', 'M19', 'M20', 'M33', 'M34', 'M55', 'M56', 'M57', 'M58', 'M59']

# %% [markdown]
# ## Transformando as medidas em parâmetros (Ótimo, bom, regular ou ruim)

# %%
# Critério quartil Crescente:
# Acima quartil 75% (incluso: Ótimo
# Entre quartil 50% (incluso) e quartil 75%: Bom
# Entre quartil 25% (incluso) e quartil 50%: Regular
# Abaixo quartil 25%: Ruim
parametros_quartis_crescentes = [
    'M7',
    'M8',
    'M9',
    'M11',
    'M12',
    'M13',
    'M17',
    'M18',
    'M19',
    'M20',
    'M21',
    'M22',
    'M23',
    'M24',
    'M25',
    'M26',
    'M27',
    'M28',
    'M30',
    'M32',
    'M35',
    'M44',
    'M47',
    'M48',
    'M49',
    'M50',
    'M51',
]
quartis = ['min','25%', '50%', '75%','max']
notas = [0, 4, 7, 10]

for M in parametros_quartis_crescentes:
    for i in range(len(notas)):
        sup = df[M].describe().loc[quartis[i+1]]
        inf = df[M].describe().loc[quartis[i]]
        df.loc[
            (
                (df[M] < sup) &
                (df[M] >= inf)
            ), 
            ('P' + M[1:])
        ] = notas[i]

# %%
# Critério quartil Derescente:
# Acima quartil 75% (incluso: Ruim
# Entre quartil 50% (incluso) e quartil 75%: Regular
# Entre quartil 25% (incluso) e quartil 50%: Bom
# Abaixo quartil 25%: Ótimo
parametros_quartis_decrescentes = [
    'M1',
    'M2',
    'M3',
    'M5', #M5 possui critérios adicionais
    'M6',
    'M10',
    'M16',
    'M29',
    'M31',
    'M32',
    'M36',
    'M37',
    'M38',
    'M39',
    'M40',
    'M41',
    'M42',
    'M43',
    'M45',
    'M46',
    'M52', #M52 possui critérios adicionais
    'M53', #M53 possui critérios adicionais
    'M54', #M54 possui critérios adicionais
]
quartis = ['min','25%', '50%', '75%','max']
notas = [10, 7, 4, 0]

for M in parametros_quartis_decrescentes:
    for i in range(len(notas)):
        sup = df[M].describe().loc[quartis[i+1]]
        inf = df[M].describe().loc[quartis[i]]
        df.loc[
            (
                (df[M] < sup) &
                (df[M] >= inf)
            ), 
            ('P' + M[1:])
        ] = notas[i]
    #Todos que foram iguais ao minimo são ótimos:
    minimal = df[M].describe().loc[quartis[0]]
    df.loc[
            df[M]==minimal, 
            ('P' + M[1:])
        ] = notas[0]

# %%
# Critério booleano positivo:
# Se >=1, então ótimo. 
# Se não, ruim.
parametros_booleanos_positivos = [
    'M4',
    'M33',
    'M34',
    'M55',
    'M55',
    'M56',
    'M57',
    'M59',
    'M58', #M58 possui critérios adicionais
]
notas = [0,1]
for M in parametros_booleanos_positivos:
    df.loc[:, ('P' + M[1:])] = notas[0]
    df.loc[
            df[M]>=1, 
            ('P' + M[1:])
        ] = notas[1]

# %%
parametros_ranges_fixos = ['M14','M15']

# %%
df.loc[
    df['M14']>=4,
    'P14'] = 10

df.loc[
    df['M14']==3,
    'P14'] = 7

df.loc[
    (df['M14']<3) & (df['M14']>=1),
    'P14'] = 4

df.loc[
    df['M14']==0,
    'P14'] = 0

# %%
df.loc[
    df['M15']==3,
    'P15'] = 10

df.loc[
    df['M15']==2,
    'P15'] = 7

df.loc[
    df['M15']==1,
    'P15'] = 4

df.loc[
    df['M15']==0,
    'P15'] = 0

# %%
parametros_com_condicoes_adicionais = ['M5', 'M52', 'M53', 'M54', 'M58']

# %%
#M5
df.loc[
    (df['D1']<=50) & (df['D8']==0),
    'P5']=0
df.loc[
    (df['D1']>0) & (df['D1']<50) & (df['D8']==0),
    'P5']=7

# %%
#M52, M53, M54, M58
df.loc[
    (df['D84']==0),
    'P51']=10

df.loc[
    (df['D86']==0),
    'P53']=10

df.loc[
    (df['D88']==0),
    'P54']=10

# %% [markdown]
# ## Indicadores

# %%
indicadores = {
    'I1': ['P1', 'P2', 'P3', 'P4', 'P5'],
    'I2': ['P6', 'P7'],
    'I3': ['P8'],
    'I4': ['P9', 'P10', 'P11'],
    'I5': ['P12', 'P13'],
    'I6': ['P14', 'P15'],
    'I7': ['P16'],
    'I8': ['P17', 'P18'],
    'I9': ['P19', 'P20'],
    'I10': ['P21', 'P22', 'P23'],
    'I11': ['P24', 'P25', 'P26'],
    'I12': ['P27', 'P28'],
    'I13': ['P29', 'P30', 'P31', 'P32'],
    'I14': ['P33'],
    'I15': ['P34'],
    'I16': ['P35'],
    'I17': ['P36'],
    'I18': ['P37', 'P38', 'P39', 'P40', 'P41', 'P42'],
    'I19': ['P43'],
    'I20': ['P44', 'P45'],
    'I21': ['P46'],
    'I22': ['P47', 'P48'],
    'I23': ['P49'],
    'I24': ['P50'],
    'I25': ['P51'],
    'I26': ['P52', 'P53', 'P54'],
    'I27': ['P55', 'P56', 'P57'],
}

# %%
notas = [0, 2.5, 5, 7.5, 10]
notas_indicadores = [0, 4, 7, 10]
for k,v in indicadores.items():
    df.loc[:,k] = df[v].mean(axis=1)
    for i in range(len(notas)-1):
        df.loc[
            (df[k]>=notas[i]) & (df[k]<notas[i+1]),
            k
        ] = notas_indicadores[i]

# %%
df[indicadores.keys()]
# Out:
#        I1    I2    I3    I4    I5   I6    I7    I8  I9   I10  ...   I18   I19  \
# 0     7.0   7.0   7.0   4.0   7.0  0.0   0.0   7.0 NaN   7.0  ...   7.0   4.0
# 1     4.0   7.0   7.0   0.0   4.0  0.0  10.0   0.0 NaN   7.0  ...  10.0   NaN
# 2     4.0   0.0   7.0   7.0   4.0  0.0   4.0   4.0 NaN  10.0  ...   4.0   NaN
# 3     7.0   7.0  10.0   7.0   7.0  0.0   4.0   0.0 NaN  10.0  ...  10.0   NaN
# 4     7.0   7.0  10.0  10.0   7.0  0.0   0.0   4.0 NaN   7.0  ...   7.0   4.0
# ..    ...   ...   ...   ...   ...  ...   ...   ...  ..   ...  ...   ...   ...
# 641  10.0   7.0   NaN   0.0  10.0  0.0  10.0   0.0 NaN  10.0  ...  10.0  10.0
# 642   4.0  10.0   4.0  10.0   4.0  0.0   0.0   7.0 NaN   0.0  ...   4.0   7.0
# 643   4.0   7.0   0.0  10.0  10.0  0.0   0.0  10.0 NaN  10.0  ...   7.0   7.0
# 644   7.0   7.0   4.0   4.0   4.0  0.0  10.0   7.0 NaN   7.0  ...   4.0   NaN
# 645   0.0   NaN   NaN   NaN   NaN  0.0  10.0   NaN NaN   NaN  ...   NaN   NaN
#
#      I20  I21  I22   I23   I24   I25  I26  I27
# 0    7.0  NaN  7.0  10.0   7.0   7.0  NaN  0.0
# 1    7.0  0.0  7.0   4.0   NaN   7.0  NaN  0.0
# 2    NaN  0.0  4.0   7.0   7.0   4.0  NaN  0.0
# 3    NaN  NaN  7.0   4.0   4.0   7.0  NaN  0.0
# 4    7.0  4.0  4.0   7.0   7.0  10.0  NaN  0.0
# ..   ...  ...  ...   ...   ...   ...  ...  ...
# 641  0.0  NaN  NaN   4.0  10.0   0.0  NaN  0.0
# 642  7.0  7.0  0.0  10.0  10.0  10.0  NaN  0.0
# 643  7.0  0.0  7.0  10.0   7.0  10.0  NaN  0.0
# 644  NaN  NaN  NaN   0.0   NaN   0.0  NaN  0.0
# 645  NaN  NaN  NaN   NaN   NaN   NaN  NaN  0.0
#
# [646 rows x 27 columns]

# %%
subdimensoes = {
    'S1': ['I1', 'I2'],
    'S2': ['I3', 'I4', 'I5'],
    'S3': ['I6', 'I7', 'I8', 'I9'],
    'S4': ['I10'],
    'S5': ['I11', 'I12', 'I13'],
    'S6': ['I14', 'I15'],
    'S7': ['I16', 'I17'],
    'S8': ['I18', 'I19', 'I20', 'I21', 'I22'],
    'S9': ['I23', 'I24', 'I25'],
    'S10': ['I26'],
    'S11': ['I27'],
}

# %%
notas = [0, 2.5, 5, 7.5, 10]
notas_subdimensoes = [0, 4, 7, 10]
for k,v in subdimensoes.items():
    df.loc[:,k] = df[v].mean(axis=1)
    for i in range(len(notas)-1):
        df.loc[
            (df[k]>=notas[i]) & (df[k]<notas[i+1]),
            k
        ] = notas_subdimensoes[i]

# %%
df[subdimensoes.keys()]
# Out:
#        S1    S2   S3    S4    S5   S6    S7    S8    S9  S10  S11
# 0     7.0   7.0  0.0   7.0   7.0  0.0   7.0   7.0  10.0  NaN  0.0
# 1     7.0   4.0  4.0   7.0   7.0  0.0   4.0   7.0   7.0  NaN  0.0
# 2     0.0   7.0  4.0  10.0   0.0  0.0   4.0   4.0   7.0  NaN  0.0
# 3     7.0  10.0  0.0  10.0  10.0  0.0   7.0  10.0   7.0  NaN  0.0
# 4     7.0  10.0  0.0   7.0   7.0  0.0   7.0   7.0  10.0  NaN  0.0
# ..    ...   ...  ...   ...   ...  ...   ...   ...   ...  ...  ...
# 641  10.0   7.0  4.0  10.0   4.0  0.0   0.0   7.0   4.0  NaN  0.0
# 642   7.0   7.0  0.0   0.0   7.0  0.0  10.0   7.0  10.0  NaN  0.0
# 643   7.0   7.0  4.0  10.0   7.0  0.0  10.0   7.0  10.0  NaN  0.0
# 644   7.0   4.0  7.0   7.0   4.0  0.0   4.0   4.0   0.0  NaN  0.0
# 645   0.0   NaN  7.0   NaN   NaN  0.0   NaN   NaN   NaN  NaN  0.0
#
# [646 rows x 11 columns]

# %%
dimensoes = {
    'DIM1': ['S1', 'S2', 'S3'],
    'DIM2': ['S4', 'S5'],
    'DIM3': ['S6', 'S7'],
    'DIM4': ['S8'],
    'DIM5': ['S9'],
    'DIM6': ['S10'],
    'DIM7': ['S11'],
}

# %%
notas = [0, 2.5, 5, 7.5, 10]
notas_dimensoes = [0, 4, 7, 10]
for k,v in dimensoes.items():
    df.loc[:,k] = df[v].mean(axis=1)
    for i in range(len(notas)-1):
        df.loc[
            (df[k]>=notas[i]) & (df[k]<notas[i+1]),
            k
        ] = notas_dimensoes[i]

# %%
df.head()
# Out:
#    cod_mun_1  cod_mun_2          mun_name   D1      D2      D3  D4     D5  D6  \
# 0   350010.0  3500105.0        Adamantina  6.0  2214.0   256.0 NaN  248.0 NaN
# 1   350020.0  3500204.0            Adolfo  1.0   728.0   140.0 NaN   51.0 NaN
# 2   350030.0  3500303.0             Aguaí  2.0  3642.0  1274.0 NaN  645.0 NaN
# 3   350040.0  3500402.0    Águas da Prata  2.0   769.0   135.0 NaN   56.0 NaN
# 4   350050.0  3500501.0  Águas de Lindóia  4.0  1481.0   346.0 NaN  201.0 NaN
#
#    D7  ...    S9  S10  S11  DIM1  DIM2  DIM3  DIM4  DIM5  DIM6  DIM7
# 0 NaN  ...  10.0  NaN  0.0   4.0   7.0   4.0   7.0  10.0   NaN   0.0
# 1 NaN  ...   7.0  NaN  0.0   7.0   7.0   0.0   7.0   7.0   NaN   0.0
# 2 NaN  ...   7.0  NaN  0.0   4.0   7.0   0.0   4.0   7.0   NaN   0.0
# 3 NaN  ...   7.0  NaN  0.0   7.0  10.0   4.0  10.0   7.0   NaN   0.0
# 4 NaN  ...  10.0  NaN  0.0   7.0   7.0   4.0   7.0  10.0   NaN   0.0
#
# [5 rows x 267 columns]

# %%
san = {'NSAN': ['DIM1', 'DIM2', 'DIM3', 'DIM4', 'DIM5', 'DIM6', 'DIM7']}

# %%
notas = [0, 2.5, 5, 7.5, 10]
notas_san = [0, 4, 7, 10]
for k,v in san.items():
    df.loc[:,k] = df[v].mean(axis=1)
    for i in range(len(notas)-1):
        df.loc[
            (df[k]>=notas[i]) & (df[k]<notas[i+1]),
            'Criterio_SAN'
        ] = notas_san[i]

# %%
df[['mun_name', 'NSAN']]
# Out:
#              mun_name      NSAN
# 0          Adamantina  5.333333
# 1              Adolfo  4.666667
# 2               Aguaí  3.666667
# 3      Águas da Prata  6.333333
# 4    Águas de Lindóia  5.833333
# ..                ...       ...
# 641    Vitória Brasil  4.166667
# 642        Votorantim  5.333333
# 643       Votuporanga  6.833333
# 644          Zacarias  3.000000
# 645               NaN  1.333333
#
# [646 rows x 2 columns]

# %%
ordered = df[['mun_name', 'NSAN']].sort_values(by='NSAN', ascending=False)

# %%
ordered = ordered.reset_index(drop=True)

# %%
ordered.loc[ordered['mun_name']=='Ribeirão Preto'][['mun_name', 'NSAN']]
# Out:
#           mun_name      NSAN
# 51  Ribeirão Preto  5.833333

# %%
df[['mun_name', 'NSAN']].sort_values(by='NSAN', ascending=True).head(10)
# Out:
#          mun_name      NSAN
# 163      Echaporã  1.166667
# 645           NaN  1.333333
# 232       Igaratá  1.333333
# 370  Nova Campina  1.333333
# 427       Piedade  1.333333
# 402     Paraibuna  1.833333
# 202      Guapiara  1.833333
# 301       Lavínia  1.833333
# 471       Queiroz  1.833333
# 602    Taquarivaí  1.833333

# %%
sns.histplot(df['NSAN'])
# Out:
# <AxesSubplot:xlabel='NSAN', ylabel='Count'>

# %%
medidas_com_dados = cols_all_nan.loc[cols_all_nan==False].index.to_list()
lista_medidas = medidas_com_dados
fig, axs = plt.subplots(len(lista_medidas),3, figsize=(10,2.5 * len(lista_medidas)))
sns.set_style('dark')
for i in range(len(lista_medidas)):
    sns.histplot(df[lista_medidas[i]], ax= axs[i, 0], color=sns.color_palette('dark')[0])
    sns.histplot(np.log1p(df[lista_medidas[i]]), ax = axs[i,1],  color=sns.color_palette('dark')[1])
    sns.histplot(df['P'+lista_medidas[i][1:]], ax = axs[i,2],  color=sns.color_palette('dark')[2])
    axs[i,1].set_xlabel(('log(' + lista_medidas[i] + ')'))
fig.tight_layout(pad=1.2)
plt.show()

# %%
sns.scatterplot(data=df.loc[df['pop2021']<df['pop2021'].max()][['pop2021', 'NSAN']], x='pop2021', y='NSAN')
# plt.xscale('log')
# Out:
# <AxesSubplot:xlabel='pop2021', ylabel='NSAN'>

# %%
gdf = gpd.read_file('./data/geojs-35-mun.json')

# %%
df = df.loc[~df['cod_mun_2'].isna()]
df.loc[:,'cod_mun_2'] = df.loc[:,'cod_mun_2'].astype('int32')
gdf.loc[:,'id'] = gdf.loc[:,'id'].astype('int32')

# %%
gdf = gdf.merge(df, how='left', left_on='id', right_on='cod_mun_2')
gdf = gpd.GeoDataFrame(data=gdf, geometry=gdf.geometry)

# %%
df[].sort_values()
# Out:
#   Input In [46]
#     df[].sort_values()
#        ^
# SyntaxError: invalid syntax

# %%
df['M36']

# %%
gdf.plot('Criterio_SAN', figsize=(10, 10), legend=True, cmap='viridis')

# %%
gdf.plot('M3', figsize=(10, 10), legend=True, cmap='viridis')

# %%
(100*df.groupby(by=['DIM5']).count() / len(df))[['cod_mun_1']].rename(columns={'cod_mun_1': 'perc'})

# %%
df[]
